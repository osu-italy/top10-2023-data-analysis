# %%
import json
out_data = {}

# %%
with open("anonymized_and_cleaned_votes.json") as f:
    data = json.load(f)

# %%
for player_vote in data:
    tierlist = player_vote["votes"]
    for vote in tierlist:
        voted = vote["choiceUsername"]
        if voted not in out_data:
            out_data[voted] = 0
        out_data[voted] += vote["weight"]

# %%
import pandas
pandas.set_option('display.max_rows', None)

df = (
    pandas.DataFrame(out_data.items(), columns=["username", "points"])
    .sort_values("points", ascending=False)
    .reset_index(drop=True)
)

# only the first 10 values
top10 = df.head(10)
top10.index += 1

df.index += 1

# %% [markdown]
# # Top 10

# %%
top10
# Out:
#            username  points
# 1              Arge  466.50
# 2         kiirochii  394.25
# 3   TheITGovernment  299.75
# 4            Jabahh  244.50
# 5          Arancino  228.75
# 6          Gigi8974  136.00
# 7           Ryuzaki  114.75
# 8            Rushio  100.25
# 9   Sakura Nenecchi   93.50
# 10            bgm16   92.75

# %% [markdown]
# # Full Leaderboard

# %%
df
# Out:
#            username  points
# 1              Arge  466.50
# 2         kiirochii  394.25
# 3   TheITGovernment  299.75
# 4            Jabahh  244.50
# 5          Arancino  228.75
# 6          Gigi8974  136.00
# 7           Ryuzaki  114.75
# 8            Rushio  100.25
# 9   Sakura Nenecchi   93.50
# 10            bgm16   92.75
# 11  TheECGovernment   73.50
# 12      Jaki 2Milli   63.50
# 13             Wido   49.00
# 14           giulio   30.00
# 15         Spazza17   28.25
# 16              mhh   24.50
# 17          Akahito   21.00
# 18    shadow modico   18.25
# 19          Markden   17.00
# 20         -Hideki-   15.00
# 21             zekk   15.00
# 22       SHEKERANDO   14.25
# 23           Ganyu1   14.25
# 24            dem72   13.75
# 25            Surpy    9.00
# 26           Toma 2    8.25
# 27            Daren    7.75
# 28           modico    7.50
# 29          DT-sama    7.00
# 30          zSmoxKe    6.75
# 31        ReviaKung    6.50
# 32           Woopak    6.50
# 33     Amnesia Haze    6.50
# 34       Kuromueina    6.25
# 35        Massimo99    6.25
# 36        Crazy Hot    5.75
# 37             -Tao    5.50
# 38         -Kazuki-    5.00
# 39            Lorax    5.00
# 40             Nyuh    4.50
# 41         MirCap72    4.25
# 42     Memento Vivi    4.00
# 43          Kyrichu    4.00
# 44          Chiicco    3.00
# 45       -Spaghetti    3.00
# 46         - Menma-    3.00
# 47          TWEEKER    2.75
# 48           Mathia    2.50
# 49         Proioxis    2.50
# 50    squartatrice_    2.50
# 51        Caparezza    2.25
# 52           Rommix    2.25
# 53    Supermattia03    2.00
# 54            oxeie    2.00
# 55  Mussolini Pizza    2.00
# 56         Trivago_    1.75
# 57     DJ YOSHITAKA    1.75
# 58         Bluecrow    1.50
# 59        Panda 4x4    1.50
# 60   KEKKOKING_0547    1.25
# 61    dt_gamesplays    1.25
# 62             Sapo    1.00
# 63           Cawolo    1.00
# 64            Kirin    1.00
# 65        MinerZeta    1.00
# 66    Bananamagic77    1.00
# 67       LePalleOsu    1.00
# 68           Lucyii    1.00
# 69            -Doki    1.00
# 70      nonsochiama    1.00
# 71            Rejax    1.00
# 72             rhyy    0.75
# 73           Zexsch    0.75
# 74           Vacsei    0.75
# 75         Skreddle    0.75
# 76          -Syncro    0.75

# %% [markdown]
# ### This is for updating the README.md file.
# You can ignore this if you are not interested

# %%
import tabulate
top10_table = tabulate.tabulate(top10, headers='keys', tablefmt='github')
full_table = tabulate.tabulate(df, headers='keys', tablefmt='github')

# %%
with open("README.md", "wt") as f:
    print("# Top 10 Italian Players of 2023", file=f)
    print("Forum Post: https://osu.ppy.sh/community/forums/topics/1864118", file=f)
    print("## Top 10 players", file=f)
    print(top10_table, file=f)
    print("## Full Players List", file=f)
    print(full_table, file=f)
