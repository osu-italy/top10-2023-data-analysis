# %%
import json
out_data = {}

# %%
with open("anonymized_and_cleaned_votes.json") as f:
    data = json.load(f)

# %%
for player_vote in data:
    tierlist = player_vote["votes"]
    for vote in tierlist:
        voted = vote["choiceUsername"]
        if voted not in out_data:
            out_data[voted] = 0
        out_data[voted] += vote["weight"]

# %%
import pandas
pandas.set_option('display.max_rows', None)

df = (
    pandas.DataFrame(out_data.items(), columns=["username", "points"])
    .sort_values("points", ascending=False)
    .reset_index(drop=True)
)

# only the first 10 values
top10 = df.head(10)
top10.index += 1

df.index += 1

# %% [markdown]
# # Top 10

# %%
top10
# Out:
#            username  points
# 1              Arge  476.00
# 2         kiirochii  403.25
# 3   TheITGovernment  298.50
# 4            Jabahh  247.75
# 5          Arancino  231.75
# 6          Gigi8974  142.00
# 7           Ryuzaki  120.25
# 8            Rushio  100.00
# 9             bgm16   97.00
# 10  Sakura Nenecchi   89.50

# %% [markdown]
# # Full Leaderboard

# %%
df
# Out:
#            username  points
# 1              Arge  476.00
# 2         kiirochii  403.25
# 3   TheITGovernment  298.50
# 4            Jabahh  247.75
# 5          Arancino  231.75
# 6          Gigi8974  142.00
# 7           Ryuzaki  120.25
# 8            Rushio  100.00
# 9             bgm16   97.00
# 10  Sakura Nenecchi   89.50
# 11  TheECGovernment   72.50
# 12      Jaki 2Milli   69.25
# 13             Wido   47.00
# 14           giulio   30.75
# 15         Spazza17   29.75
# 16              mhh   24.50
# 17          Akahito   21.00
# 18    shadow modico   18.25
# 19         -Hideki-   15.00
# 20             zekk   15.00
# 21           Ganyu1   14.25
# 22       SHEKERANDO   14.25
# 23            dem72   13.75
# 24            Surpy   12.00
# 25           Woopak   10.25
# 26          Markden   10.25
# 27           Toma 2    9.75
# 28            Daren    7.75
# 29           modico    7.50
# 30        Crazy Hot    7.25
# 31          DT-sama    7.00
# 32          zSmoxKe    6.75
# ...

# %% [markdown]
# ### This is for updating the README.md file.
# You can ignore this if you are not interested

# %%
import tabulate
top10_table = tabulate.tabulate(top10, headers='keys', tablefmt='github')
full_table = tabulate.tabulate(df, headers='keys', tablefmt='github')

# %%
with open("README.md", "wt") as f:
    print("# Top 10 Italian Players of 2023", file=f)
    print("Forum Post: https://osu.ppy.sh/community/forums/topics/1864118", file=f)
    print("## Top 10 players", file=f)
    print(top10_table, file=f)
    print("## Full Players List", file=f)
    print(full_table, file=f)
